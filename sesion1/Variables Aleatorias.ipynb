# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from scipy.stats import norm

# %%
N = 10000
x_normal = np.random.normal(scale = 2, loc = 1, size = N)

# %%
plt.figure('Datos simulados de una Normal')
plt.hist(x_normal, bins = 50)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  1.,   0.,   0.,   0.,   0.,   0.,   2.,   1.,   6.,  10.,  16.,
#          20.,  31.,  40.,  60.,  89., 135., 146., 228., 275., 328., 426.,
#         524., 547., 547., 632., 624., 638., 616., 604., 589., 518., 448.,
#         425., 351., 281., 240., 176., 116.,  97.,  70.,  42.,  34.,  24.,
#          15.,  11.,   9.,   4.,   1.,   3.]),
#  array([-7.97378011, -7.64713066, -7.32048122, -6.99383177, -6.66718232,
#         -6.34053287, -6.01388342, -5.68723398, -5.36058453, -5.03393508,
#         -4.70728563, -4.38063619, -4.05398674, -3.72733729, -3.40068784,
#         -3.0740384 , -2.74738895, -2.4207395 , -2.09409005, -1.7674406 ,
#         -1.44079116, -1.11414171, -0.78749226, -0.46084281, -0.13419337,
#          0.19245608,  0.51910553,  0.84575498,  1.17240442,  1.49905387,
#          1.82570332,  2.15235277,  2.47900222,  2.80565166,  3.13230111,
#          3.45895056,  3.78560001,  4.11224945,  4.4388989 ,  4.76554835,
#          5.0921978 ,  5.41884724,  5.74549669,  6.07214614,  6.39879559,
#          6.72544504,  7.05209448,  7.37874393,  7.70539338,  8.03204283,
#          8.35869227]),
#  <BarContainer object of 50 artists>)

# %%
norm.cdf(0, loc = 1, scale = 0.7)
# Out:
# 0.07656372550983476

# %%
norm.ppf(0.05)
# Out:
# -1.6448536269514729

# %%
x_exp = np.random.exponential(scale = 1/10, size = N)

# %%
plt.figure('Histograma datos exponenciales')
plt.hist(x_exp)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([6.062e+03, 2.397e+03, 9.180e+02, 3.850e+02, 1.380e+02, 6.300e+01,
#         2.700e+01, 5.000e+00, 2.000e+00, 3.000e+00]),
#  array([1.66131409e-05, 9.25729676e-02, 1.85129322e-01, 2.77685676e-01,
#         3.70242031e-01, 4.62798385e-01, 5.55354740e-01, 6.47911094e-01,
#         7.40467449e-01, 8.33023803e-01, 9.25580158e-01]),
#  <BarContainer object of 10 artists>)
